# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
import scipy.stats as stat

# %%
# Import and clean data
df = pd.read_csv('df_kernel_3_tight.csv')
df.drop(columns = 'Unnamed: 0', inplace = True)
df[::20]
# Out:
#      Wavelength  Activity  Detection  Correlation
# 0             3  0.706675       True     0.617142
# 20           23  0.018264       True     0.394264
# 40           43  0.005776       True     0.508473
# 60           63  0.003158       True     0.310970
# 80           83  0.002030       True     0.194909
# 100         103  0.001591       True     0.523613

# %%
# Plot
figure(figsize = (35, 15))
sns.set_style("darkgrid")

plt.set_cmap("gray")
# plt.subplot(121)

plt.subplot(121)
sns.scatterplot(x = 'Activity', y = 'Correlation', data = df)
plt.xscale('log')

plt.subplot(122)
sns.scatterplot(x = 'Activity', y = 'Detection', data = df)
plt.xscale('log')

# %%
# Calculate correlation and significance level
correlation, p_value = stat.pearsonr(df['Correlation'], df['Activity'])
print(f"Correlation: {round(correlation, 3)}")
print(f"P Value: {round(p_value, 6)}")
# Out:
# Correlation: 0.284
# P Value: 0.001638

# %%
# Calculate correlation and significance level
correlation, p_value = stat.pearsonr(df['Detection'], df['Activity'])
print(f"Correlation: {round(correlation, 3)}")
print(f"P Value: {round(p_value, 6)}")
# Out:
# Correlation: 0.121
# P Value: 0.188565

# %%
# Calculate correlation and significance level
correlation, p_value = stat.pearsonr(df['Detection'], df['Activity'])
print(f"Correlation: {round(correlation, 3)}")
print(f"P Value: {round(p_value, 6)}")
# Out:
# Correlation: 0.121
# P Value: 0.188565
