# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
import scipy.stats as stat

# %%
# Import and clean data
df = pd.read_csv('df_kernel_25.csv')
df.drop(columns = 'Unnamed: 0', inplace = True)
df[::50]
# Out:
#      Wavelength  Activity  Detection  Correlation
# 0             3  0.678912       True     0.617142
# 50          253  0.011479       True     0.403824
# 100         503  0.002918       True     0.179016
# 150         753  0.001398      False     0.069201
# 200        1003  0.000712      False     0.069201

# %%
# Plot
figure(figsize = (35, 15))
sns.set_style("darkgrid")

plt.set_cmap("gray")
# plt.subplot(121)

plt.subplot(121)
sns.scatterplot(x = 'Activity', y = 'Correlation', data = df)
plt.xscale('log')

plt.subplot(122)
sns.scatterplot(x = 'Activity', y = 'Detection', data = df)
plt.xscale('log')

# %%
# Calculate correlation and significance level
correlation, p_value = stat.pearsonr(df['Detection'], df['Activity'])
print(f"Correlation: {round(correlation, 3)}")
print(f"P Value: {round(p_value, 6)}")
# Out:
# Correlation: 0.539
# P Value: 0.0
