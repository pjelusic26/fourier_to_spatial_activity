# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
import scipy.stats as stat

# %%
# Import and clean data
df = pd.read_csv('df_kernel_3.csv')
df.drop(columns = 'Unnamed: 0', inplace = True)
df[::50]
# Out:
#      Wavelength  Activity  Detection  Correlation
# 0             3  0.706675       True     0.617142
# 50          253  0.000567       True     0.403824
# 100         503  0.000278       True     0.179016
# 150         753  0.000098      False     0.069201
# 200        1003  0.000010      False     0.069201

# %%
df = df.head(40)
print(df.shape)
df[::5]
# Out:
# (40, 4)
#     Wavelength  Activity  Detection  Correlation
# 0            3  0.706675       True     0.617142
# 5           28  0.012482       True     0.345414
# 10          53  0.003428       True     0.161554
# 15          78  0.001538       True     0.109987
# 20         103  0.001591       True     0.523613
# 25         128  0.001222       True     0.791832
# 30         153  0.000610      False     0.075842
# 35         178  0.000766       True     0.108774

# %%
# Plot
figure(figsize = (35, 15))
sns.set_style("darkgrid")

plt.set_cmap("gray")
# plt.subplot(121)

plt.subplot(121)
sns.scatterplot(x = 'Activity', y = 'Correlation', data = df)
# plt.xscale('log')

plt.subplot(122)
sns.scatterplot(x = 'Activity', y = 'Detection', data = df)
# plt.xscale('log')
# Out:
# <AxesSubplot:xlabel='Activity', ylabel='Detection'>

# %%
# Calculate correlation and significance level
correlation, p_value = stat.pearsonr(df['Correlation'], df['Activity'])
print(f"Correlation: {round(correlation, 3)}")
print(f"P Value: {round(p_value, 6)}")
# Out:
# Correlation: 0.398
# P Value: 0.010973

# %%
# Calculate correlation and significance level
correlation, p_value = stat.pearsonr(df['Detection'], df['Activity'])
print(f"Correlation: {round(correlation, 3)}")
print(f"P Value: {round(p_value, 6)}")
# Out:
# Correlation: 0.196
# P Value: 0.050835
