# %%
import numpy as np
import matplotlib.pyplot as plt
import f2s
from matplotlib.pyplot import figure

# %%
# Get fourier and spatial domain
figure(figsize = (15, 15))
fourier, spatial = f2s.f2s(3, 0, 'YES')

# %%
# Get fourier and spatial domain
figure(figsize = (15, 15))
fourier, spatial = f2s.f2s(50, 0, 'YES')

# %%
# Get fourier and spatial domain
figure(figsize = (15, 15))
fourier, spatial = f2s.f2s(500, 0, 'YES')
